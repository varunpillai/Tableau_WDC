# %%
import urllib3

url='http://beringmedia.helpserve.com/api/index.php?e=/Tickets/Ticket/ListAll/12,17,18,19,20,21,23,24,25,29,30/4,5,6,7,8,9/&apikey=c9d160ae-0802-d194-5990-7ff6fb07889f&salt=75996179&signature=f2YHCCJYVzLdGrd9MjPA0CvmHEPyXwAcmkjXk6Sldhs%3D'

http = urllib3.PoolManager()
r = http.request('GET', url)
r.status
# Out:
# 200

# %%
r.data
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<tickets>\n<ticket id="155341" flagtype="0">\n<displayid><![CDATA[UKV-812-90995]]></displayid>\n<departmentid><![CDATA[23]]></departmentid>\n<statusid><![CDATA[9]]></statusid>\n<priorityid><![CDATA[15]]></priorityid>\n<typeid><![CDATA[1]]></typeid>\n<userid><![CDATA[926]]></userid>\n<userorganization />\n<userorganizationid />\n<ownerstaffid><![CDATA[58]]></ownerstaffid>\n<ownerstaffname><![CDATA[Emily Scoles]]></ownerstaffname>\n<fullname><![CDATA[Nick Rongione]]></fullname>\n<email><![CDATA[nick.rongione@audiencepartners.com]]></email>\n<lastreplier><![CDATA[Emily Scoles]]></lastreplier>\n<subject><![CDATA[Phone System Adjustments]]></subject>\n<creationtime><![CDATA[1484786949]]></creationtime>\n<lastactivity><![CDATA[1487949324]]></lastactivity>\n<laststaffreply><![CDATA[1487949324]]></laststaffreply>\n<lastuserreply><![CDATA[0]]></lastuserreply>\n<slaplanid><![CDATA[6]]></slaplanid>\n<nextreplydue><![CDATA[0]]></nextreplydue>\n<resolutiondue><![CDATA[1506521184]]></resolutiondue>\n<replies><![CDATA[1]]></replies>\n<ipaddress><![CDATA[63.139.52.34]]></ipaddress>\n<creator><![CDATA[1]]></creator>\n<creationmode><![CDATA[2]]></creationmode>\n<creationtype><![CDATA[1]]></creationtype>\n<isescalated><![CDATA[0]]></isescalated>\n<escalationruleid><![CDATA[0]]></escalationruleid>\n<templategroupid><![CDATA[3]]></templategroupid>\n<tags><![CDATA[phone]]></tags>\n<templategroupname><![CDATA[AdPlatformCustomers]]></templategroupname>\n<note type="ticket" id="4532" ticketid="155341" notecolor="1" creatorstaffid="45" forstaffid="0" creatorstaffname="Nick Rongione" creationdate="1485200350"><![CDATA[please schedule a 30 minute call with me, you and the phone guy so we can learn about phone system configuration]]></note>\n<note type="ticket" id="4569" ticketid="155341" notecolor="1" creatorstaffid="45" forstaffid="0" creatorstaffname="Nick Rongione" creationdate="1485793787"><![CDATA[Tarah, please take a \'resolution manager\' posture on this and get it done by COB Tuesday. (unless that is fully impossible for some reason)]]></note>\n<note type="ticket" id="4642" ticketid="155341" notecolor="1" creatorstaffid="48" forstaffid="0" creatorstaffname="Tarah Laurent" creationdate="1486503006"><![CDATA[Nick, Alonna has taken over the phone issue. ]]></note>\n<note type="ticket" id="4705" ticketid="155341" notecolor="1" creatorstaffid="45" forstaffid="0" creatorstaffname="Nick Rongione" creationdate="1487948805"><![CDATA[How\'s phone system stuff going Em?]]></note>\n</ticket>\n<ticket id="155355" flagtype="0">\n<displayid><![CDATA[LKM-193-89543]]></displayid>\n<departmentid><![CDATA[23]]></departmentid>\n<statusid><![CDATA[6]]></statusid>\n<priorityid><![CDATA[13]]></priorityid>\n<typeid><![CDATA[10]]></typeid>\n<userid><![CDATA[926]]></userid>\n<userorganization />\n<userorganizationid />\n<ownerstaffid><![CDATA[48]]></ownerstaffid>\n<ownerstaffname><![CDATA[Tarah Laurent]]></ownerstaffname>\n<fullname><![CDATA[Nick Rongione]]></fullname>\n<email><![CDATA[nick.rongione@audiencepartners.com]]></email>\n<lastreplier><![CDATA[Nick Rongione]]></lastreplier>\n<subject><![CDATA[Prepare Weekly Sales Report]]></subject>\n<creationtime><![CDATA[1484834701]]></creationtime>\n<lastactivity><![CDATA[1484834701]]></lastactivity>\n<laststaffreply><![CDATA[1484834701]]></laststaffreply>\n<lastuserreply><![CDATA[0]]></lastuserreply>\n<slaplanid><![CDATA[0]]></slaplanid>\n<nextreplydue><![CDATA[0]]></nextreplydue>\n<resolutiondue><![CDATA[0]]></resolutiondue>\n<replies><![CDATA[0]]></replies>\n<ipaddress><![CDATA[63.139.52.34]]></ipaddress>\n<creator><![CDATA[1]]></creator>\n<creationmode><![CDATA[2]]></creationmode>\n<creationtype><![CDATA[1]]></creationtype>\n<isescalated><![CDATA[0]]></isescalated>\n<escalationruleid><![CDATA[0]]></escalationruleid>\n<templategroupid><![CDATA[3]]></templategroupid>\n<tags />\n<templategroupname><![CDATA[AdPlatformCustomers]]></templategroupname>\n</ticket>\n<ticket id="155378" fla ...
